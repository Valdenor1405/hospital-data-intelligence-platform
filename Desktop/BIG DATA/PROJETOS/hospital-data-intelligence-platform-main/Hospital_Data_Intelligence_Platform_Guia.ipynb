# %% [markdown]
# # Hospital Data Intelligence Platform
# ## Guia Técnico
#
# Este notebook apresenta a arquitetura, pipeline e componentes do projeto de Engenharia de Dados Hospitalar.

# %% [markdown]
# ## Objetivos
# - Demonstrar uma arquitetura Lakehouse.
# - Construir um pipeline Bronze → Silver → Gold.
# - Modelagem dimensional.
# - Dashboard executivo.
# - API FastAPI.
# - Base para IA, MLOps e DevOps.

# %% [markdown]
# ## Arquitetura do Projeto
# 1. Geração/ingestão de dados
# 2. Bronze
# 3. Silver
# 4. Data Quality
# 5. Gold (KPIs)
# 6. Data Warehouse
# 7. DuckDB
# 8. Dashboard Streamlit
# 9. FastAPI

# %%
# Estrutura resumida do projeto
from pathlib import Path

root = Path(".")
for p in sorted(root.iterdir()):
    print(p.name)

# %% [markdown]
# ## Pipeline Bronze

# %%
print('python src/ingestion/bronze_ingestion.py')

# %% [markdown]
# ## Pipeline Silver

# %%
print('python src/processing/silver_processing.py')

# %% [markdown]
# ## Data Quality

# %%
print('python src/quality/data_quality.py')

# %% [markdown]
# ## Camada Gold

# %%
print('python src/transformations/gold_kpis.py')

# %% [markdown]
# ## Data Warehouse

# %%
print('python src/transformations/warehouse_builder.py')

# %% [markdown]
# ## DuckDB

# %%
import duckdb
print("DuckDB disponível para consultas analíticas.")

# %% [markdown]
# ## Pipeline completo

# %%
print('python run_pipeline.py')

# %% [markdown]
# ## Dashboard

# %%
print('streamlit run dashboard/app.py')

# %% [markdown]
# ## API

# %%
print('uvicorn src.api.main:app --reload')

# %% [markdown]
# ## Tecnologias Utilizadas
#
# - Python
# - Pandas
# - DuckDB
# - Streamlit
# - FastAPI
# - Plotly
# - Pytest
# - Docker
# - Git/GitHub

# %% [markdown]
# ## Evoluções planejadas
#
# - MLflow
# - Airflow
# - Kafka
# - Great Expectations
# - Evidently AI
# - Terraform
# - Kubernetes
# - Azure
# - AWS
# - Databricks
